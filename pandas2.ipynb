# %%
import pandas as pd

# %%
import numpy as np

# %%
d=pd.date_range('20/5/2020',periods=7,freq='y')
d
# Out:
# DatetimeIndex(['2020-12-31', '2021-12-31', '2022-12-31', '2023-12-31',
#                '2024-12-31', '2025-12-31', '2026-12-31'],
#               dtype='datetime64[ns]', freq='A-DEC')

# %%
pd.date_range('20/5/2020','20/6/2020')
# Out:
# DatetimeIndex(['2020-05-20', '2020-05-21', '2020-05-22', '2020-05-23',
#                '2020-05-24', '2020-05-25', '2020-05-26', '2020-05-27',
#                '2020-05-28', '2020-05-29', '2020-05-30', '2020-05-31',
#                '2020-06-01', '2020-06-02', '2020-06-03', '2020-06-04',
#                '2020-06-05', '2020-06-06', '2020-06-07', '2020-06-08',
#                '2020-06-09', '2020-06-10', '2020-06-11', '2020-06-12',
#                '2020-06-13', '2020-06-14', '2020-06-15', '2020-06-16',
#                '2020-06-17', '2020-06-18', '2020-06-19', '2020-06-20'],
#               dtype='datetime64[ns]', freq='D')

# %%
np.arange(0,7,0.2)
# Out:
# array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. , 2.2, 2.4,
#        2.6, 2.8, 3. , 3.2, 3.4, 3.6, 3.8, 4. , 4.2, 4.4, 4.6, 4.8, 5. ,
#        5.2, 5.4, 5.6, 5.8, 6. , 6.2, 6.4, 6.6, 6.8])

# %%
pd.Series(np.arange(2,9),index=pd.date_range('20/5/2020',periods=7,index))
# Out:
# 2020-05-20    2
# 2020-05-21    3
# 2020-05-22    4
# 2020-05-23    5
# 2020-05-24    6
# 2020-05-25    7
# 2020-05-26    8
# Freq: D, dtype: int32

# %%
s=pd.Series(['sai','lokesh',1,2,3],index=[0,1,2,3,4])
s
# Out:
# 0       sai
# 1    lokesh
# 2         1
# 3         2
# 4         3
# dtype: object

# %%
 s[1]
# Out:
# 'lokesh'

# %%
import csv

# %%
f=open('datset.csv')

# %%
f
# Out:
# <_io.TextIOWrapper name='datset.csv' mode='r' encoding='cp1252'>

# %%
for i in f:
    print(f)
# Out:
# <_io.TextIOWrapper name='datset.csv' mode='r' encoding='cp1252'>
# <_io.TextIOWrapper name='datset.csv' mode='r' encoding='cp1252'>
# <_io.TextIOWrapper name='datset.csv' mode='r' encoding='cp1252'>
# <_io.TextIOWrapper name='datset.csv' mode='r' encoding='cp1252'>

# %%
c=csv.reader(f)
for i in c:
    print(i)
# Out:
# ['a', 'b', 'c', 'd', 'message']
# ['1', '2', '3', '4', 'hello']
# ['5', '6', '7', '8', 'world']
# ['9', '10', '11', '12', 'foo']

# %%
with open('datset.csv') as f:
    lines=list(csv.reader(f))

# %%
lines
# Out:
# [['a', 'b', 'c', 'd', 'message'],
#  ['1', '2', '3', '4', 'hello'],
#  ['5', '6', '7', '8', 'world'],
#  ['9', '10', '11', '12', 'foo']]

# %%
a=[1,2]
b=[5,6]
d=[4,8,9]
c=list(zip(a,b,d))
c
# Out:
# [(1, 5, 4), (2, 6, 8)]

# %%
lines[1:]
# Out:
# [['1', '2', '3', '4', 'hello'],
#  ['5', '6', '7', '8', 'world'],
#  ['9', '10', '11', '12', 'foo']]

# %%
list1=list(zip(lines[1],lines[2],lines[3]))
list1
# Out:
# [('1', '5', '9'),
#  ('2', '6', '10'),
#  ('3', '7', '11'),
#  ('4', '8', '12'),
#  ('hello', 'world', 'foo')]

# %%
list2=list(zip(lines[0],list1))
list2
# Out:
# [('a', ('1', '5', '9')),
#  ('b', ('2', '6', '10')),
#  ('c', ('3', '7', '11')),
#  ('d', ('4', '8', '12')),
#  ('message', ('hello', 'world', 'foo'))]

# %%
a={k:v for k,v in list2}
a
# Out:
# {'a': ('1', '5', '9'),
#  'b': ('2', '6', '10'),
#  'c': ('3', '7', '11'),
#  'd': ('4', '8', '12'),
#  'message': ('hello', 'world', 'foo')}

# %%
a=pd.read_csv('datset.csv')
a
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
a.to_json('pp.json',orient='records')

# %%
import requests

# %%
url='https://www.json.org/example.html'
r=requests.get(url)

# %%
type(r)
# Out:
# requests.models.Response

# %%
obj=""""
{"glossary": {
        "title": "example glossary",
		"GlossDiv": {
            "title": "S",
          lossList": {
                "GlossEntry": {
             	"SortAs": "SGML",
		       "ID": "SGML",
						"GlossTerm": "Standard Generalized Markup Language",
			"Acronym": "SGML",
					"Abbrev": "ISO 8879:1986",
					"GlossDef": {
                        "para": "A meta-markup language, used to create markup languages such as DocBook.",
						"GlossSeeAlso": ["GML", "XML"]
                    },
					"GlossSee": "markup"
                }
            }
        }
    }
}"""

# %%
import json

# %%
a=pd.read_csv('C:\\Users\\sai lokesh\\Desktop\\net.csv')
a
# Out:
#        1             Quincy Acy   PF   24
# 0      2           Jordan Adams   SG   20
# 1      3           Steven Adams    C   21
# 2      4            Jeff Adrien   PF   28
# 3      5          Arron Afflalo   SG   29
# 4      5          Arron Afflalo   SG   29
# 5      5          Arron Afflalo   SG   29
# 6      6          Alexis Ajinça    C   26
# 7      7         Furkan Aldemir   PF   23
# 8      8           Cole Aldrich    C   26
# 9      9      LaMarcus Aldridge   PF   29
# 10    10            Lavoy Allen    C   25
# 11    11             Tony Allen   SG   33
# 12    12        Al-Farouq Aminu   SF   24
# 13    13           Lou Amundson   PF   32
# 14    13           Lou Amundson   PF   32
# 15    13           Lou Amundson   PF   32
# 16    14         Chris Andersen    C   36
# 17    15          Alan Anderson   SG   32
# 18    16          Kyle Anderson   SF   21
# 19    17          Ryan Anderson   PF   26
# 20    18  Giannis Antetokounmpo   SG   20
# ...

# %%
a['newcolimn']=1

# %%
a
# Out:
#        1             Quincy Acy   PF   24  newcolimn
# 0      2           Jordan Adams   SG   20          1
# 1      3           Steven Adams    C   21          1
# 2      4            Jeff Adrien   PF   28          1
# 3      5          Arron Afflalo   SG   29          1
# 4      5          Arron Afflalo   SG   29          1
# 5      5          Arron Afflalo   SG   29          1
# 6      6          Alexis Ajinça    C   26          1
# 7      7         Furkan Aldemir   PF   23          1
# 8      8           Cole Aldrich    C   26          1
# 9      9      LaMarcus Aldridge   PF   29          1
# 10    10            Lavoy Allen    C   25          1
# 11    11             Tony Allen   SG   33          1
# 12    12        Al-Farouq Aminu   SF   24          1
# 13    13           Lou Amundson   PF   32          1
# 14    13           Lou Amundson   PF   32          1
# 15    13           Lou Amundson   PF   32          1
# 16    14         Chris Andersen    C   36          1
# ...

# %%
a.head()
# Out:
#    1     Quincy Acy  PF  24  newcolimn
# 0  2   Jordan Adams  SG  20          1
# 1  3   Steven Adams   C  21          1
# 2  4    Jeff Adrien  PF  28          1
# 3  5  Arron Afflalo  SG  29          1
# 4  5  Arron Afflalo  SG  29          1

# %%
a
# Out:
#        1             Quincy Acy   PF   24  newcolimn
# 0      2           Jordan Adams   SG   20          1
# 1      3           Steven Adams    C   21          1
# 2      4            Jeff Adrien   PF   28          1
# 3      5          Arron Afflalo   SG   29          1
# 4      5          Arron Afflalo   SG   29          1
# 5      5          Arron Afflalo   SG   29          1
# 6      6          Alexis Ajinça    C   26          1
# 7      7         Furkan Aldemir   PF   23          1
# 8      8           Cole Aldrich    C   26          1
# 9      9      LaMarcus Aldridge   PF   29          1
# 10    10            Lavoy Allen    C   25          1
# 11    11             Tony Allen   SG   33          1
# 12    12        Al-Farouq Aminu   SF   24          1
# 13    13           Lou Amundson   PF   32          1
# 14    13           Lou Amundson   PF   32          1
# 15    13           Lou Amundson   PF   32          1
# 16    14         Chris Andersen    C   36          1
# ...

# %%
a['date']=d
d
# Out:
# DatetimeIndex(['2020-05-31', '2020-06-30', '2020-07-31', '2020-08-31',
#                '2020-09-30', '2020-10-31', '2020-11-30', '2020-12-31',
#                '2021-01-31', '2021-02-28',
#                ...
#                '2075-09-30', '2075-10-31', '2075-11-30', '2075-12-31',
#                '2076-01-31', '2076-02-29', '2076-03-31', '2076-04-30',
#                '2076-05-31', '2076-06-30'],
#               dtype='datetime64[ns]', length=674, freq='M')

# %%
d=pd.date_range('20/5/2020',periods=674,freq='m')

# %%
a
# Out:
#        1             Quincy Acy   PF   24       date
# 0      2           Jordan Adams   SG   20 2020-05-31
# 1      3           Steven Adams    C   21 2020-06-30
# 2      4            Jeff Adrien   PF   28 2020-07-31
# 3      5          Arron Afflalo   SG   29 2020-08-31
# 4      5          Arron Afflalo   SG   29 2020-09-30
# 5      5          Arron Afflalo   SG   29 2020-10-31
# 6      6          Alexis Ajinça    C   26 2020-11-30
# 7      7         Furkan Aldemir   PF   23 2020-12-31
# 8      8           Cole Aldrich    C   26 2021-01-31
# 9      9      LaMarcus Aldridge   PF   29 2021-02-28
# 10    10            Lavoy Allen    C   25 2021-03-31
# 11    11             Tony Allen   SG   33 2021-04-30
# 12    12        Al-Farouq Aminu   SF   24 2021-05-31
# 13    13           Lou Amundson   PF   32 2021-06-30
# 14    13           Lou Amundson   PF   32 2021-07-31
# 15    13           Lou Amundson   PF   32 2021-08-31
# 16    14         Chris Andersen    C   36 2021-09-30
# ...

# %%
a.dtypes
# Out:
# 1                     object
# Quincy Acy            object
# PF                    object
# 24                    object
# date          datetime64[ns]
# dtype: object

# %%
p.to_json()
# Out:
# '{"User ID":{"0":15624510,"1":15810944,"2":15668575,"3":15603246,"4":15804002,"5":15728773,"6":15598044,"7":15694829,"8":15600575,"9":15727311,"10":15570769,"11":15606274,"12":15746139,"13":15704987,"14":15628972,"15":15697686,"16":15733883,"17":15617482,"18":15704583,"19":15621083,"20":15649487,"21":15736760,"22":15714658,"23":15599081,"24":15705113,"25":15631159,"26":15792818,"27":15633531,"28":15744529,"29":15669656,"30":15581198,"31":15729054,"32":15573452,"33":15776733,"34":15724858,"35":15713144,"36":15690188,"37":15689425,"38":15671766,"39":15782806,"40":15764419,"41":15591915,"42":15772798,"43":15792008,"44":15715541,"45":15639277,"46":15798850,"47":15776348,"48":15727696,"49":15793813,"50":15694395,"51":15764195,"52":15744919,"53":15671655,"54":15654901,"55":15649136,"56":15775562,"57":15807481,"58":15642885,"59":15789109,"60":15814004,"61":15673619,"62":15595135,"63":15583681,"64":15605000,"65":15718071,"66":15679760,"67":15654574,"68":15577178,"69":15595324,"70":15756932,"
# ...

# %%
p=pd.read_csv(r'C:\Users\sai lokesh\Desktop\Social_Network_Ads.csv')

# %%
ds=pd.read_html('https://communities.sas.com/t5/General-SAS-Programming/Create-New-Dataset-using-only-specific-dates-rows/td-p/434326')

# %%
ds[0].
# Out:
#              0   1
# 0         Date  aa
# 1   1990-02-02  23
# 2   1990-02-07  45
# 3   1990-02-13  56
# 4   1990-02-28   7
# 5   1990-03-12   8
# 6   1990-03-13   8
# 7   1990-03-16   9
# 8   1990-03-19  55
# 9   1990-03-23  78
# 10  1990-04-03  90
# 11  1990-04-23  76
# 12  1990-05-01   6
# 13  1990-05-11   4
# 14  1990-05-15  33
# 15  1990-05-25  34
# 16  1990-05-30  12

# %%
new_header=ds[0].iloc[0]
ds[0]=ds[0][1:]
ds[0].columns=new_header

# %%
ds[0]
# Out:
# 0         Date  aa
# 1   1990-02-02  23
# 2   1990-02-07  45
# 3   1990-02-13  56
# 4   1990-02-28   7
# 5   1990-03-12   8
# 6   1990-03-13   8
# 7   1990-03-16   9
# 8   1990-03-19  55
# 9   1990-03-23  78
# 10  1990-04-03  90
# 11  1990-04-23  76
# 12  1990-05-01   6
# 13  1990-05-11   4
# 14  1990-05-15  33
# 15  1990-05-25  34
# 16  1990-05-30  12

# %%
d=pd.to_datetime(ds[0]['Date'])

# %%
d
# Out:
# 1    1990-02-02
# 2    1990-02-07
# 3    1990-02-13
# 4    1990-02-28
# 5    1990-03-12
# 6    1990-03-13
# 7    1990-03-16
# 8    1990-03-19
# 9    1990-03-23
# 10   1990-04-03
# 11   1990-04-23
# 12   1990-05-01
# 13   1990-05-11
# 14   1990-05-15
# 15   1990-05-25
# 16   1990-05-30
# Name: Date, dtype: datetime64[ns]

# %%
ds[0]['Date']=d
# Out:
# C:\Users\sai lokesh\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
ds[0]
# Out:
# 0        Date  aa
# 1  1990-02-02  23
# 2  1990-02-07  45
# 3  1990-02-13  56
# 4  1990-02-28   7
# 5  1990-03-12   8
# 6  1990-03-13   8
# 7  1990-03-16   9
# 8  1990-03-19  55
# 9  1990-03-23  78
# 10 1990-04-03  90
# 11 1990-04-23  76
# 12 1990-05-01   6
# 13 1990-05-11   4
# 14 1990-05-15  33
# 15 1990-05-25  34
# 16 1990-05-30  12

# %%
ds[0].dtypes
# Out:
# 0
# Date    datetime64[ns]
# aa              object
# dtype: object

# %%
d.dt.year.value_counts()
# Out:
# 1990    16
# Name: Date, dtype: int64

# %%
ds[0].shape
# Out:
# (16, 2)

# %%
ds[0].index
# Out:
# RangeIndex(start=1, stop=17, step=1)
