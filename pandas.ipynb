# %%
import pandas as pd

# %%
# %%writefile 'datset.csv'
# a,b,c,d,message
# 1,2,3,4,hello
# 5,6,7,8,world
# 9,10,11,12,foo
# Out:
# Overwriting datset.csv

# %%
a=pd.read_csv('datset.csv')

# %%
a
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
type(a)
# Out:
# pandas.core.frame.DataFrame

# %%
a.head()
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
a.head(n=2)
# Out:
#    a  b  c  d message
# 0  1  2  3  4   hello
# 1  5  6  7  8   world

# %%
a.tail(2)
# Out:
#    a   b   c   d message
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
a.dtypes
# Out:
# a           int64
# b           int64
# c           int64
# d           int64
# message    object
# dtype: object

# %%
a['d']
# Out:
# 0     4
# 1     8
# 2    12
# Name: d, dtype: int64

# %%
type(a['d'])
# Out:
# pandas.core.series.Series

# %%
list(a['d'])
# Out:
# [4, 8, 12]

# %%
a[['d']]
# Out:
#     d
# 0   4
# 1   8
# 2  12

# %%
a[['d','a']]
# Out:
#     d  a
# 0   4  1
# 1   8  5
# 2  12  9

# %%
df=pd.read_csv('datset.csv',header=None)

# %%
df
# Out:
#    0   1   2   3        4
# 0  a   b   c   d  message
# 1  1   2   3   4    hello
# 2  5   6   7   8    world
# 3  9  10  11  12      foo

# %%
# %%writefile 'vadla.tsv'
#
# sudh  sudh  sudh  sudh  sudh  sudh
# kumar kumar kumar kumar kumar kumar
# Out:
# Overwriting vadla.tsv

# %%
pd.read_table('vadla.tsv',header=None)
# Out:
#                                      0
# 0   sudh  sudh  sudh  sudh  sudh  sudh
# 1  kumar kumar kumar kumar kumar kumar

# %%
a=pd.read_csv('datset.csv',header=None,names=['x','y','z','a','b'])

# %%
a
# Out:
#    x   y   z   a        b
# 0  a   b   c   d  message
# 1  1   2   3   4    hello
# 2  5   6   7   8    world
# 3  9  10  11  12      foo

# %%
# %%writefile 'test.csv'
# #hey
# a,b,c,d,message
# #how r u
# #i am fine
# 1,2,3,4,NA
# 5,6,,8,world
# 9,10,11,12,foo
# Out:
# Overwriting test.csv

# %%
df=pd.read_csv('test.csv',skiprows=[0,2,3],na_values=[1])

# %%
df
# Out:
#      a   b     c   d message
# 0  NaN   2   3.0   4     NaN
# 1  5.0   6   NaN   8   world
# 2  9.0  10  11.0  12     foo

# %%
# %%writefile 'vsl.xlsx'
# %%writefile 'kl.xslx'
# a,b,c,d,message
# 1,2,3,4,hello
# 5,6,7,8,world
# 9,10,11,12,foo
# %%writefile 'kp.xslx'
# a,b,c,d,message
# 1,2,3,4,hello
# 5,6,7,8,world
# 9,10,11,12
# Out:
# Overwriting vsl.xlsx

# %%
df2=pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')

# %%
df2
# Out:
# [      Rk                 Player  Pos  Age   Tm   G  GS    MP   FG   FGA  ...   \
#  0      1             Quincy Acy   PF   24  NYK  68  22  1287  152   331  ...
#  1      2           Jordan Adams   SG   20  MEM  30   0   248   35    86  ...
#  2      3           Steven Adams    C   21  OKC  70  67  1771  217   399  ...
#  3      4            Jeff Adrien   PF   28  MIN  17   0   215   19    44  ...
#  4      5          Arron Afflalo   SG   29  TOT  78  72  2502  375   884  ...
#  5      5          Arron Afflalo   SG   29  DEN  53  53  1750  281   657  ...
#  6      5          Arron Afflalo   SG   29  POR  25  19   752   94   227  ...
#  7      6          Alexis Ajinça    C   26  NOP  68   8   957  181   329  ...
#  8      7         Furkan Aldemir   PF   23  PHI  41   9   540   40    78  ...
#  9      8           Cole Aldrich    C   26  NYK  61  16   976  144   301  ...
#  10     9      LaMarcus Aldridge   PF   29  POR  71  71  2512  659  1415  ...
# ...

# %%
df2[0][[]]
# Out:
#       Rk                 Player  Pos  Age   Tm   G  GS    MP   FG   FGA  ...   \
# 0      1             Quincy Acy   PF   24  NYK  68  22  1287  152   331  ...
# 1      2           Jordan Adams   SG   20  MEM  30   0   248   35    86  ...
# 2      3           Steven Adams    C   21  OKC  70  67  1771  217   399  ...
# 3      4            Jeff Adrien   PF   28  MIN  17   0   215   19    44  ...
# 4      5          Arron Afflalo   SG   29  TOT  78  72  2502  375   884  ...
# 5      5          Arron Afflalo   SG   29  DEN  53  53  1750  281   657  ...
# 6      5          Arron Afflalo   SG   29  POR  25  19   752   94   227  ...
# 7      6          Alexis Ajinça    C   26  NOP  68   8   957  181   329  ...
# 8      7         Furkan Aldemir   PF   23  PHI  41   9   540   40    78  ...
# 9      8           Cole Aldrich    C   26  NYK  61  16   976  144   301  ...
# 10     9      LaMarcus Aldridge   PF   29  POR  71  71  2512  659  1415  ...
# ...

# %%
df2[0][['Rk','Player','Pos','Age']].to_csv('C:\\Users\\sai lokesh\\Desktop\\net.csv',index=False,header=None,columns=['Rk','Player','Pos','Age'])

# %%
pwd()
# Out:
# 'C:\\Users\\sai lokesh'

# %%
df2[0].columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
df2[0][['Rk','Player','Pos','Age']]
# Out:
#       Rk                 Player  Pos  Age
# 0      1             Quincy Acy   PF   24
# 1      2           Jordan Adams   SG   20
# 2      3           Steven Adams    C   21
# 3      4            Jeff Adrien   PF   28
# 4      5          Arron Afflalo   SG   29
# 5      5          Arron Afflalo   SG   29
# 6      5          Arron Afflalo   SG   29
# 7      6          Alexis Ajinça    C   26
# 8      7         Furkan Aldemir   PF   23
# 9      8           Cole Aldrich    C   26
# 10     9      LaMarcus Aldridge   PF   29
# 11    10            Lavoy Allen    C   25
# 12    11             Tony Allen   SG   33
# 13    12        Al-Farouq Aminu   SF   24
# 14    13           Lou Amundson   PF   32
# 15    13           Lou Amundson   PF   32
# 16    13           Lou Amundson   PF   32
# 17    14         Chris Andersen    C   36
# 18    15          Alan Anderson   SG   32
# 19    16          Kyle Anderson   SF   21
# 20    17          Ryan Anderson   PF   26
# ...

# %%
df2[0].head()
# Out:
#   Rk         Player Pos Age   Tm   G  GS    MP   FG  FGA  ...    FT%  ORB  \
# 0  1     Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...   .784   79
# 1  2   Jordan Adams  SG  20  MEM  30   0   248   35   86  ...   .609    9
# 2  3   Steven Adams   C  21  OKC  70  67  1771  217  399  ...   .502  199
# 3  4    Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...   .579   23
# 4  5  Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...   .843   27
#
#    DRB  TRB  AST STL BLK  TOV   PF   PTS
# 0  222  301   68  27  22   60  147   398
# 1   19   28   16  16   7   14   24    94
# 2  324  523   66  38  86   99  222   537
# 3   54   77   15   4   9    9   30    60
# 4  220  247  129  41   7  116  167  1035
#
# [5 rows x 30 columns]
